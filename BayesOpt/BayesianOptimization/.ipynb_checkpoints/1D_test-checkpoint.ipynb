# %%
import math
import torch
import gpytorch
from matplotlib import pyplot as plt
from torch.autograd import Variable

from torch import optim
from gpytorch.kernels import RBFKernel
from gpytorch.means import ConstantMean
from gpytorch.likelihoods import GaussianLikelihood
from gpytorch.random_variables import GaussianRandomVariable

from torch.distributions.normal import Normal
from matplotlib import gridspec

import itertools

from dimension import Real,Integer, Categorical,DImension
from bayesian_optimization import BayesianOptimization
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

torch.cuda.set_device(3)

# %%
space = [Real(-5,15),Integer(4,15) ]
print(space.getsamples)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-8df6b6411920> in <module>()
#       1 space = [Real(-5,15),Integer(4,15) ]
# ----> 2 print(space.getsamples)
#
# AttributeError: 'list' object has no attribute 'getsamples'

# %%
class ExactGPModel(gpytorch.models.ExactGP):
    def __init__(self, train_x, train_y, likelihood):
        super(ExactGPModel, self).__init__(train_x, train_y, likelihood)
        # Our mean function is constant in the interval [-2,2]
        self.mean_module = ConstantMean(constant_bounds=(-2,2))
        # We use the RBF kernel as a universal approximator
        self.covar_module = RBFKernel(log_lengthscale_bounds=(-6, 6))
    
    def forward(self, x):
        mean_x = self.mean_module(x)
        covar_x = self.covar_module(x)
        # Return model output as GaussianRandomVariable
        return GaussianRandomVariable(mean_x, covar_x)

# %%
#minimize target function
def target(x):
    return -1*(3* torch.exp(-(x - 2)**2) + 2*torch.exp(-(x - 6)**2/8) + 1/ (x**2 + 1)+torch.randn(x.size()) * .1 )


# Training data is 6 points in [-5,15] inclusive regularly spaced
train_x = torch.linspace(-5, 15, 6)
# True function with Gaussian noise N(0,0.01)
# Maximize the negative target function
train_y = -1*target(train_x)

likelihood = GaussianLikelihood(log_noise_bounds=(-8, -6))
model = ExactGPModel(train_x.data, train_y.data, likelihood)

search_space = [Real(-5,15)]

# %%
#train before optimization
model.train()
likelihood.train()
optimizer = torch.optim.Adam([
        {'params': model.parameters()},  # Includes GaussianLikelihood parameters
    ], lr=0.1)
    # "Loss" for GPs - the marginal log likelihood
mll = gpytorch.mlls.ExactMarginalLogLikelihood(likelihood, model)

training_iter = 10
for i in range(training_iter):
        # Zero gradients from previous iteration
    optimizer.zero_grad()
        # Output from model
    output = model(train_x)
        # Calc loss and backprop gradients
    loss = -mll(output, train_y)
    loss.backward()

    print('Iter %d/%d - Loss: %.3f   log_lengthscale: %.3f   log_noise: %.3f' % (
        i + 1, training_iter, loss.data[0],
        model.covar_module.log_lengthscale.data[0, 0],
        model.likelihood.log_noise.data[0]
        ))
  
    optimizer.step()

f, observed_ax = plt.subplots(1, 1, figsize=(4, 3))
observed_ax.plot(train_x.data.numpy(), train_y.data.numpy(), 'k*')
test_x = Variable(torch.linspace(-5, 15, 100))
model.eval()
likelihood.eval()
observed_pred = likelihood(model(test_x))
observed_ax.plot(test_x.data.numpy(),observed_pred.mean().data.numpy(), 'b')
# Out:
# Iter 1/10 - Loss: 3.925   log_lengthscale: 0.000   log_noise: -6.000
# Iter 2/10 - Loss: 3.857   log_lengthscale: 0.100   log_noise: -6.000
# Iter 3/10 - Loss: 3.898   log_lengthscale: 0.191   log_noise: -6.000
# Iter 4/10 - Loss: 3.940   log_lengthscale: 0.282   log_noise: -6.000
# Iter 5/10 - Loss: 3.951   log_lengthscale: 0.357   log_noise: -6.000
# Iter 6/10 - Loss: 3.929   log_lengthscale: 0.439   log_noise: -6.000
# Iter 7/10 - Loss: 3.888   log_lengthscale: 0.526   log_noise: -6.000
# Iter 8/10 - Loss: 3.838   log_lengthscale: 0.613   log_noise: -6.000
# Iter 9/10 - Loss: 3.769   log_lengthscale: 0.703   log_noise: -6.013
# Iter 10/10 - Loss: 3.720   log_lengthscale: 0.797   log_noise: -6.055

# %%
bo = BayesianOptimization(model, likelihood, target, search_space,"discrete_mes")

bo.optimal(10,plot=True)
# Out:
# after: self.model.train_inputs tensor([[ -5.0000],
#         [ -1.0000],
#         [  3.0000],
#         [  7.0000],
#         [ 11.0000],
#         [ 15.0000],
#         [  4.9499]])
# Iter 1/10 - Loss: 2.885
# Iter 2/10 - Loss: 3.082
# Iter 3/10 - Loss: 2.713
# Iter 4/10 - Loss: 2.977
# Iter 5/10 - Loss: 2.682
# Iter 6/10 - Loss: 2.901
# Iter 7/10 - Loss: 2.988
# Iter 8/10 - Loss: 3.206
# Iter 9/10 - Loss: 2.917
# Iter 10/10 - Loss: 3.315
# after: self.model.train_inputs tensor([[ -5.0000],
#         [ -1.0000],
#         [  3.0000],
#         [  7.0000],
#         [ 11.0000],
#         [ 15.0000],
#         [  4.9499],
#         [  2.6476]])
# Iter 1/10 - Loss: 9.062
# Iter 2/10 - Loss: 7.780
# Iter 3/10 - Loss: 7.469
# Iter 4/10 - Loss: 6.381
# Iter 5/10 - Loss: 5.283
# Iter 6/10 - Loss: 4.986
# Iter 7/10 - Loss: 4.531
# Iter 8/10 - Loss: 4.264
# Iter 9/10 - Loss: 3.691
# Iter 10/10 - Loss: 3.986
# after: self.model.train_inputs tensor([[ -5.0000],
#         [ -1.0000],
#         [  3.0000],
#         [  7.0000],
#         [ 11.0000],
#         [ 15.0000],
#         [  4.9499],
#         [  2.6476],
#         [  1.9469]])
# Iter 1/10 - Loss: 3.098
# Iter 2/10 - Loss: 2.982
# Iter 3/10 - Loss: 3.018
# Iter 4/10 - Loss: 3.121
# Iter 5/10 - Loss: 2.916
# Iter 6/10 - Loss: 3.012
# Iter 7/10 - Loss: 2.794
# Iter 8/10 - Loss: 2.815
# Iter 9/10 - Loss: 3.034
# Iter 10/10 - Loss: 2.961
# after: self.model.train_inputs tensor([[ -5.0000],
#         [ -1.0000],
#         [  3.0000],
#         [  7.0000],
#         [ 11.0000],
#         [ 15.0000],
#         [  4.9499],
#         [  2.6476],
#         [  1.9469],
#         [  1.9269]])
# Iter 1/10 - Loss: 2.188
# Iter 2/10 - Loss: 2.225
# Iter 3/10 - Loss: 2.448
# Iter 4/10 - Loss: 2.419
# Iter 5/10 - Loss: 2.279
# Iter 6/10 - Loss: 2.422
# Iter 7/10 - Loss: 2.326
# Iter 8/10 - Loss: 2.241
# Iter 9/10 - Loss: 2.671
# Iter 10/10 - Loss: 2.550
# after: self.model.train_inputs tensor([[ -5.0000],
#         [ -1.0000],
#         [  3.0000],
#         [  7.0000],
#         [ 11.0000],
#         [ 15.0000],
#         [  4.9499],
#         [  2.6476],
#         [  1.9469],
#         [  1.9269],
#         [  1.9670]])
# Iter 1/10 - Loss: 2.048
# Iter 2/10 - Loss: 1.935
# Iter 3/10 - Loss: 1.591
# Iter 4/10 - Loss: 1.876
# Iter 5/10 - Loss: 1.796
# Iter 6/10 - Loss: 1.906
# Iter 7/10 - Loss: 1.738
# Iter 8/10 - Loss: 1.552
# Iter 9/10 - Loss: 1.755
# Iter 10/10 - Loss: 1.800
# after: self.model.train_inputs tensor([[ -5.0000],
#         [ -1.0000],
#         [  3.0000],
#         [  7.0000],
#         [ 11.0000],
#         [ 15.0000],
#         [  4.9499],
#         [  2.6476],
#         [  1.9469],
#         [  1.9269],
#         [  1.9670],
#         [  1.9670]])
# Iter 1/10 - Loss: 2.285
# Iter 2/10 - Loss: 1.908
# Iter 3/10 - Loss: 1.538
# Iter 4/10 - Loss: 1.985
# Iter 5/10 - Loss: 1.539
# Iter 6/10 - Loss: 1.621
# Iter 7/10 - Loss: 1.692
# Iter 8/10 - Loss: 1.697
# Iter 9/10 - Loss: 1.623
# Iter 10/10 - Loss: 1.896
# after: self.model.train_inputs tensor([[ -5.0000],
#         [ -1.0000],
#         [  3.0000],
#         [  7.0000],
#         [ 11.0000],
#         [ 15.0000],
#         [  4.9499],
#         [  2.6476],
#         [  1.9469],
#         [  1.9269],
#         [  1.9670],
#         [  1.9670],
#         [  1.9269]])
# Iter 1/10 - Loss: 1.543
# Iter 2/10 - Loss: 1.661
# Iter 3/10 - Loss: 1.649
# Iter 4/10 - Loss: 1.603
# Iter 5/10 - Loss: 2.046
# Iter 6/10 - Loss: 1.884
# Iter 7/10 - Loss: 2.127
# Iter 8/10 - Loss: 1.885
# Iter 9/10 - Loss: 2.265
# Iter 10/10 - Loss: 2.143
# after: self.model.train_inputs tensor([[ -5.0000],
#         [ -1.0000],
#         [  3.0000],
#         [  7.0000],
#         [ 11.0000],
#         [ 15.0000],
#         [  4.9499],
#         [  2.6476],
#         [  1.9469],
#         [  1.9269],
#         [  1.9670],
#         [  1.9670],
#         [  1.9269],
#         [  1.9670]])
# Iter 1/10 - Loss: 2.335
# Iter 2/10 - Loss: 2.365
# Iter 3/10 - Loss: 2.300
# Iter 4/10 - Loss: 2.017
# Iter 5/10 - Loss: 1.991
# Iter 6/10 - Loss: 2.134
# Iter 7/10 - Loss: 2.087
# Iter 8/10 - Loss: 1.595
# Iter 9/10 - Loss: 2.019
# Iter 10/10 - Loss: 1.596
# after: self.model.train_inputs tensor([[ -5.0000],
#         [ -1.0000],
#         [  3.0000],
#         [  7.0000],
#         [ 11.0000],
#         [ 15.0000],
#         [  4.9499],
#         [  2.6476],
#         [  1.9469],
#         [  1.9269],
#         [  1.9670],
#         [  1.9670],
#         [  1.9269],
#         [  1.9670],
#         [  2.0270]])
# Iter 1/10 - Loss: 1.356
# Iter 2/10 - Loss: 1.292
# Iter 3/10 - Loss: 1.867
# Iter 4/10 - Loss: 1.323
# Iter 5/10 - Loss: 1.850
# Iter 6/10 - Loss: 1.533
# Iter 7/10 - Loss: 1.602
# Iter 8/10 - Loss: 1.798
# Iter 9/10 - Loss: 1.793
# Iter 10/10 - Loss: 1.970
# after: self.model.train_inputs tensor([[ -5.0000],
#         [ -1.0000],
#         [  3.0000],
#         [  7.0000],
#         [ 11.0000],
#         [ 15.0000],
#         [  4.9499],
#         [  2.6476],
#         [  1.9469],
#         [  1.9269],
#         [  1.9670],
#         [  1.9670],
#         [  1.9269],
#         [  1.9670],
#         [  2.0270],
#         [  1.9469]])
# Iter 1/10 - Loss: 2.093
# Iter 2/10 - Loss: 1.933
# Iter 3/10 - Loss: 1.496
# Iter 4/10 - Loss: 1.651
# Iter 5/10 - Loss: 1.328
# Iter 6/10 - Loss: 1.346
# Iter 7/10 - Loss: 1.302
# Iter 8/10 - Loss: 1.333
# Iter 9/10 - Loss: 1.345
# Iter 10/10 - Loss: 1.213

# %%
print(bo.x_star)
print(bo.y_star.view(-1))
# Out:
# tensor([ 2.1071])
# tensor([-3.6203])

# %%
train_x = torch.tensor([[1,99,55],[2,98,44]])
tuple(tri.unsqueeze(-1) if tri.ndimension() == 1 else tri for tri in (train_x,))[0].size()
# Out:
# torch.Size([2, 3])
