# %%
import math
import torch
import gpytorch
from matplotlib import pyplot as plt
from torch.autograd import Variable

from torch import optim
from gpytorch.kernels import RBFKernel
from gpytorch.means import ConstantMean
from gpytorch.likelihoods import GaussianLikelihood
from gpytorch.random_variables import GaussianRandomVariable

from torch.distributions.normal import Normal
from matplotlib import gridspec
import acquisition_function as acqf
import discrete_mes as mes
import discrete_ucb as ucb
import discrete_ei as ei
import discrete_pi as pi
import itertools

from dimension import Real,Integer, Categorical,Dimension
from bayesian_optimization import BayesianOptimization
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

torch.cuda.set_device(3)

# %%
class ExactGPModel(gpytorch.models.ExactGP):
    def __init__(self, train_x, train_y, likelihood):
        super(ExactGPModel, self).__init__(train_x, train_y, likelihood)
        # Our mean function is constant in the interval [-5,15]
        self.mean_module = ConstantMean(constant_bounds=(-5,15))
        # We use the RBF kernel as a universal approximator
        self.covar_module = RBFKernel(log_lengthscale_bounds=(-6, 6))
    
    def forward(self, x):
        mean_x = self.mean_module(x)
        covar_x = self.covar_module(x)
        # Return model output as GaussianRandomVariable
        return GaussianRandomVariable(mean_x, covar_x)

# %%
#minimize target function
def target(x):
    return -1*(3* torch.exp(-(x - 2)**2) + 2*torch.exp(-(x - 6)**2/8) + 1/ (x**2 + 1)+torch.randn(x.size()) * .1 )


# Training data is 6 points in [-5,15] inclusive regularly spaced
train_x = Variable(torch.linspace(-5, 15, 6))
# True function with Gaussian noise N(0,0.01)
# Maximize the negative target function
train_y = Variable(-1*target(train_x))

likelihood = GaussianLikelihood(log_noise_bounds=(-8, -6))
model = ExactGPModel(train_x.data, train_y.data, likelihood)

search_space = [Real(-5,15)]

# %%
#train before optimization
model.train()
likelihood.train()
optimizer = torch.optim.Adam([
        {'params': model.parameters()},  # Includes GaussianLikelihood parameters
    ], lr=0.1)
    # "Loss" for GPs - the marginal log likelihood
mll = gpytorch.mlls.ExactMarginalLogLikelihood(likelihood, model)

training_iter = 10
for i in range(training_iter):
        # Zero gradients from previous iteration
    optimizer.zero_grad()
        # Output from model
    output = model(train_x)
        # Calc loss and backprop gradients
    loss = -mll(output, train_y)
    loss.backward()

    print('Iter %d/%d - Loss: %.3f   log_lengthscale: %.3f   log_noise: %.3f' % (
        i + 1, training_iter, loss.data[0],
        model.covar_module.log_lengthscale.data[0, 0],
        model.likelihood.log_noise.data[0]
        ))
  
    optimizer.step()
# Out:
# Iter 1/10 - Loss: 1.594   log_lengthscale: 0.000   log_noise: 0.000
# Iter 2/10 - Loss: 1.556   log_lengthscale: 0.100   log_noise: -0.100
# Iter 3/10 - Loss: 1.578   log_lengthscale: 0.190   log_noise: -0.200
# Iter 4/10 - Loss: 1.606   log_lengthscale: 0.269   log_noise: -0.299
# Iter 5/10 - Loss: 1.617   log_lengthscale: 0.350   log_noise: -0.395
# Iter 6/10 - Loss: 1.612   log_lengthscale: 0.433   log_noise: -0.489
# Iter 7/10 - Loss: 1.598   log_lengthscale: 0.519   log_noise: -0.580
# Iter 8/10 - Loss: 1.576   log_lengthscale: 0.602   log_noise: -0.671
# Iter 9/10 - Loss: 1.553   log_lengthscale: 0.689   log_noise: -0.761
# Iter 10/10 - Loss: 1.547   log_lengthscale: 0.780   log_noise: -0.851

# %%
bo = BayesianOptimization(model, likelihood, target, search_space,"discrete_ucb")

# %%
bo.optimal(10,plot=True)
# Out:
# Iter 1/10 - Loss: 1.416   log_lengthscale: 0.875   log_noise: -0.942
# Iter 2/10 - Loss: 1.349   log_lengthscale: 0.975   log_noise: -1.042
# Iter 3/10 - Loss: 1.237   log_lengthscale: 1.074   log_noise: -1.142
# Iter 4/10 - Loss: 1.170   log_lengthscale: 1.173   log_noise: -1.242
# Iter 5/10 - Loss: 1.130   log_lengthscale: 1.273   log_noise: -1.342
# Iter 6/10 - Loss: 1.075   log_lengthscale: 1.372   log_noise: -1.442
# Iter 7/10 - Loss: 1.059   log_lengthscale: 1.462   log_noise: -1.542
# Iter 8/10 - Loss: 1.028   log_lengthscale: 1.550   log_noise: -1.643
# Iter 9/10 - Loss: 1.021   log_lengthscale: 1.635   log_noise: -1.744
# Iter 10/10 - Loss: 1.016   log_lengthscale: 1.689   log_noise: -1.844
# Iter 1/10 - Loss: 0.938   log_lengthscale: 1.713   log_noise: -1.945
# Iter 2/10 - Loss: 0.931   log_lengthscale: 1.613   log_noise: -2.045
# Iter 3/10 - Loss: 0.947   log_lengthscale: 1.534   log_noise: -2.141
# Iter 4/10 - Loss: 0.951   log_lengthscale: 1.498   log_noise: -2.232
# Iter 5/10 - Loss: 0.947   log_lengthscale: 1.484   log_noise: -2.324
# Iter 6/10 - Loss: 0.967   log_lengthscale: 1.506   log_noise: -2.411
# Iter 7/10 - Loss: 0.968   log_lengthscale: 1.522   log_noise: -2.487
# Iter 8/10 - Loss: 0.968   log_lengthscale: 1.542   log_noise: -2.534
# Iter 9/10 - Loss: 1.008   log_lengthscale: 1.565   log_noise: -2.577
# Iter 10/10 - Loss: 1.014   log_lengthscale: 1.602   log_noise: -2.590
# Iter 1/10 - Loss: 0.926   log_lengthscale: 1.649   log_noise: -2.584
# Iter 2/10 - Loss: 0.899   log_lengthscale: 1.549   log_noise: -2.484
# Iter 3/10 - Loss: 0.880   log_lengthscale: 1.622   log_noise: -2.529
# Iter 4/10 - Loss: 0.868   log_lengthscale: 1.616   log_noise: -2.579
# Iter 5/10 - Loss: 0.860   log_lengthscale: 1.634   log_noise: -2.586
# Iter 6/10 - Loss: 0.835   log_lengthscale: 1.627   log_noise: -2.605
# Iter 7/10 - Loss: 0.823   log_lengthscale: 1.581   log_noise: -2.617
# Iter 8/10 - Loss: 0.810   log_lengthscale: 1.535   log_noise: -2.606
# Iter 9/10 - Loss: 0.844   log_lengthscale: 1.497   log_noise: -2.603
# Iter 10/10 - Loss: 0.815   log_lengthscale: 1.471   log_noise: -2.597
# Iter 1/10 - Loss: 0.758   log_lengthscale: 1.452   log_noise: -2.604
# Iter 2/10 - Loss: 0.821   log_lengthscale: 1.352   log_noise: -2.704
# Iter 3/10 - Loss: 0.823   log_lengthscale: 1.396   log_noise: -2.801
# Iter 4/10 - Loss: 0.766   log_lengthscale: 1.464   log_noise: -2.834
# Iter 5/10 - Loss: 0.759   log_lengthscale: 1.501   log_noise: -2.868
# Iter 6/10 - Loss: 0.776   log_lengthscale: 1.487   log_noise: -2.880
# Iter 7/10 - Loss: 0.838   log_lengthscale: 1.472   log_noise: -2.868
# Iter 8/10 - Loss: 0.826   log_lengthscale: 1.469   log_noise: -2.841
# Iter 9/10 - Loss: 0.858   log_lengthscale: 1.463   log_noise: -2.811
# Iter 10/10 - Loss: 0.955   log_lengthscale: 1.472   log_noise: -2.791
# Iter 1/10 - Loss: 0.891   log_lengthscale: 1.493   log_noise: -2.751
# Iter 2/10 - Loss: 0.902   log_lengthscale: 1.593   log_noise: -2.651
# Iter 3/10 - Loss: 0.853   log_lengthscale: 1.597   log_noise: -2.552
# Iter 4/10 - Loss: 0.834   log_lengthscale: 1.539   log_noise: -2.485
# Iter 5/10 - Loss: 0.845   log_lengthscale: 1.475   log_noise: -2.448
# Iter 6/10 - Loss: 0.827   log_lengthscale: 1.448   log_noise: -2.407
# Iter 7/10 - Loss: 0.789   log_lengthscale: 1.448   log_noise: -2.399
# Iter 8/10 - Loss: 0.819   log_lengthscale: 1.437   log_noise: -2.408
# Iter 9/10 - Loss: 0.777   log_lengthscale: 1.442   log_noise: -2.428
# Iter 10/10 - Loss: 0.753   log_lengthscale: 1.455   log_noise: -2.460
# Iter 1/10 - Loss: 0.683   log_lengthscale: 1.448   log_noise: -2.479
# Iter 2/10 - Loss: 0.730   log_lengthscale: 1.348   log_noise: -2.579
# Iter 3/10 - Loss: 0.696   log_lengthscale: 1.361   log_noise: -2.675
# Iter 4/10 - Loss: 0.773   log_lengthscale: 1.339   log_noise: -2.758
# Iter 5/10 - Loss: 0.768   log_lengthscale: 1.341   log_noise: -2.810
# Iter 6/10 - Loss: 0.791   log_lengthscale: 1.331   log_noise: -2.848
# Iter 7/10 - Loss: 0.822   log_lengthscale: 1.369   log_noise: -2.840
# Iter 8/10 - Loss: 0.775   log_lengthscale: 1.429   log_noise: -2.815
# Iter 9/10 - Loss: 0.775   log_lengthscale: 1.477   log_noise: -2.784
# Iter 10/10 - Loss: 0.796   log_lengthscale: 1.489   log_noise: -2.743
# Iter 1/10 - Loss: 0.742   log_lengthscale: 1.481   log_noise: -2.704
# Iter 2/10 - Loss: 0.782   log_lengthscale: 1.581   log_noise: -2.804
# Iter 3/10 - Loss: 0.804   log_lengthscale: 1.566   log_noise: -2.745
# Iter 4/10 - Loss: 0.808   log_lengthscale: 1.504   log_noise: -2.714
# Iter 5/10 - Loss: 0.866   log_lengthscale: 1.439   log_noise: -2.724
# Iter 6/10 - Loss: 0.903   log_lengthscale: 1.397   log_noise: -2.767
# Iter 7/10 - Loss: 0.945   log_lengthscale: 1.381   log_noise: -2.811
# Iter 8/10 - Loss: 0.965   log_lengthscale: 1.407   log_noise: -2.867
# Iter 9/10 - Loss: 0.985   log_lengthscale: 1.455   log_noise: -2.884
# Iter 10/10 - Loss: 1.018   log_lengthscale: 1.497   log_noise: -2.898
# Iter 1/10 - Loss: 0.961   log_lengthscale: 1.519   log_noise: -2.882
# Iter 2/10 - Loss: 0.994   log_lengthscale: 1.419   log_noise: -2.782
# Iter 3/10 - Loss: 1.056   log_lengthscale: 1.401   log_noise: -2.841
# Iter 4/10 - Loss: 1.085   log_lengthscale: 1.453   log_noise: -2.908
# Iter 5/10 - Loss: 1.150   log_lengthscale: 1.525   log_noise: -2.957
# Iter 6/10 - Loss: 1.176   log_lengthscale: 1.607   log_noise: -2.939
# Iter 7/10 - Loss: 1.225   log_lengthscale: 1.647   log_noise: -2.891
# Iter 8/10 - Loss: 1.283   log_lengthscale: 1.686   log_noise: -2.828
# Iter 9/10 - Loss: 1.312   log_lengthscale: 1.689   log_noise: -2.754
# Iter 10/10 - Loss: 1.363   log_lengthscale: 1.681   log_noise: -2.677
# Iter 1/10 - Loss: 1.306   log_lengthscale: 1.666   log_noise: -2.608
# Iter 2/10 - Loss: 1.262   log_lengthscale: 1.766   log_noise: -2.708
# Iter 3/10 - Loss: 1.241   log_lengthscale: 1.859   log_noise: -2.741
# Iter 4/10 - Loss: 1.182   log_lengthscale: 1.806   log_noise: -2.692
# Iter 5/10 - Loss: 1.124   log_lengthscale: 1.733   log_noise: -2.642
# Iter 6/10 - Loss: 1.090   log_lengthscale: 1.653   log_noise: -2.610
# Iter 7/10 - Loss: 1.039   log_lengthscale: 1.625   log_noise: -2.590
# Iter 8/10 - Loss: 1.009   log_lengthscale: 1.592   log_noise: -2.598
# Iter 9/10 - Loss: 0.970   log_lengthscale: 1.567   log_noise: -2.621
# Iter 10/10 - Loss: 0.927   log_lengthscale: 1.540   log_noise: -2.659
# Iter 1/10 - Loss: 0.810   log_lengthscale: 1.523   log_noise: -2.711
# Iter 2/10 - Loss: 0.838   log_lengthscale: 1.423   log_noise: -2.811
# Iter 3/10 - Loss: 0.886   log_lengthscale: 1.458   log_noise: -2.910
# Iter 4/10 - Loss: 0.900   log_lengthscale: 1.479   log_noise: -3.006
# Iter 5/10 - Loss: 0.952   log_lengthscale: 1.453   log_noise: -3.089
# Iter 6/10 - Loss: 0.983   log_lengthscale: 1.456   log_noise: -3.167
# Iter 7/10 - Loss: 1.041   log_lengthscale: 1.475   log_noise: -3.235
# Iter 8/10 - Loss: 1.075   log_lengthscale: 1.506   log_noise: -3.269
# Iter 9/10 - Loss: 1.130   log_lengthscale: 1.552   log_noise: -3.273
# Iter 10/10 - Loss: 1.174   log_lengthscale: 1.570   log_noise: -3.259

# %%
print(bo.x_star)
print(bo.y_star.view(-1))
# Out:
# tensor([ 2.0270])
# tensor([-3.4716])

# %%
train_x = torch.tensor([[1,99,55],[2,98,44]])
tuple(tri.unsqueeze(-1) if tri.ndimension() == 1 else tri for tri in (train_x,))[0].size()
# Out:
# torch.Size([2, 3])
